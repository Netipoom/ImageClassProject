# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import torch
from torchvision import datasets, transforms,models
from torch import nn
from time import time,sleep
from PIL import Image
import numpy as np
import os
import random
import matplotlib.pyplot as plt
from collections import OrderedDict
from torch import nn, optim
import torch.nn.functional as F

# %%
import signal

from contextlib import contextmanager

import requests


DELAY = INTERVAL = 4 * 60  # interval time in seconds
MIN_DELAY = MIN_INTERVAL = 2 * 60
KEEPALIVE_URL = "https://nebula.udacity.com/api/v1/remote/keep-alive"
TOKEN_URL = "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token"
TOKEN_HEADERS = {"Metadata-Flavor":"Google"}


def _request_handler(headers):
    def _handler(signum, frame):
        requests.request("POST", KEEPALIVE_URL, headers=headers)
    return _handler


@contextmanager
def active_session(delay=DELAY, interval=INTERVAL):
    """
    Example:

    from workspace_utils import active session

    with active_session():
        # do long-running work here
    """
    token = requests.request("GET", TOKEN_URL, headers=TOKEN_HEADERS).text
    headers = {'Authorization': "STAR " + token}
    delay = max(delay, MIN_DELAY)
    interval = max(interval, MIN_INTERVAL)
    original_handler = signal.getsignal(signal.SIGALRM)
    try:
        signal.signal(signal.SIGALRM, _request_handler(headers))
        signal.setitimer(signal.ITIMER_REAL, delay, interval)
        yield
    finally:
        signal.signal(signal.SIGALRM, original_handler)
        signal.setitimer(signal.ITIMER_REAL, 0)


def keep_awake(iterable, delay=DELAY, interval=INTERVAL):
    """
    Example:

    from workspace_utils import keep_awake

    for i in keep_awake(range(5)):
        # do iteration with lots of work here
    """
    with active_session(delay, interval): yield from iterable

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
data_transforms = transforms.Compose([transforms.Resize(255),
                                 transforms.CenterCrop(224),
                                 transforms.ToTensor(),
                                 transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])
# TODO: Load the datasets with ImageFolder
train_datasets = datasets.ImageFolder(train_dir, transform=data_transforms)
valid_datasets = datasets.ImageFolder(valid_dir, transform=data_transforms)
test_datasets = datasets.ImageFolder(test_dir, transform=data_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloaders = torch.utils.data.DataLoader(train_datasets, batch_size=64, shuffle=True)
validloaders = torch.utils.data.DataLoader(valid_datasets, batch_size=64, shuffle=True)
testloaders = torch.utils.data.DataLoader(test_datasets, batch_size=64, shuffle=True)

# %%
model = models.vgg13(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg13-c768596a.pth" to /root/.torch/models/vgg13-c768596a.pth
# 100%|██████████| 532194478/532194478 [00:05<00:00, 100302970.14it/s]

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# <font color='red'>**Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.</font>

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from torch import nn, optim
import torch.nn.functional as F
for param in model.parameters():
    param.requires_grad = False
from collections import OrderedDict
classifier = nn.Sequential(OrderedDict([
                          ('fc1', nn.Linear(25088, 1024)),
                          ('relu1', nn.ReLU()),
                          ('dropout1',nn.Dropout(p=0.2)),
                          ('fc2', nn.Linear(1024, 512)),
                          ('relu2', nn.ReLU()),
                          ('dropout2',nn.Dropout(p=0.4)),
                          ('fc3', nn.Linear(512, 255)),
                          ('relu3', nn.ReLU()),
                          ('dropout3',nn.Dropout(p=0.3)),
                          ('fc4', nn.Linear(255, 102)),
                          ('output', nn.LogSoftmax(dim=1))
                          ]))
    
model.classifier = classifier
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.003)

# %%
model.to(device);

# %%
epochs = 15
steps = 0
running_loss = 0
print_every = 5
with active_session():
    for epoch in range(epochs):
        start = time()
        for inputs, labels in trainloaders:
            steps += 1
            # Move input and label tensors to the default device
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()

            logps = model.forward(inputs)
            loss = criterion(logps, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            if steps % print_every == 0:
                test_loss = 0
                accuracy = 0
                model.eval()
                with torch.no_grad():
                    for inputs, labels in validloaders:
                        inputs, labels = inputs.to(device), labels.to(device)
                        logps = model.forward(inputs)
                        batch_loss = criterion(logps, labels)

                        test_loss += batch_loss.item()

                        # Calculate accuracy
                        ps = torch.exp(logps)
                        top_p, top_class = ps.topk(1, dim=1)
                        equals = top_class == labels.view(*top_class.shape)
                        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

                print(f"Epoch {epoch+1}/{epochs}.. "
                      f"Train loss: {running_loss/print_every:.3f}.. "
                      f"Valid loss: {test_loss/len(validloaders):.3f}.. "
                      f"Valid accuracy: {accuracy/len(validloaders):.3f}")
                running_loss = 0
                model.train()
            
        end_time=time()
        tot_time=end_time-start
        print(f"Epoch {epoch+1}..total time: {tot_time}")
# Out:
# Epoch 1/15.. Train loss: 5.153.. Valid loss: 4.542.. Valid accuracy: 0.042
# Epoch 1/15.. Train loss: 4.482.. Valid loss: 4.401.. Valid accuracy: 0.068
# Epoch 1/15.. Train loss: 4.444.. Valid loss: 4.259.. Valid accuracy: 0.099
# Epoch 1/15.. Train loss: 4.248.. Valid loss: 3.962.. Valid accuracy: 0.141
# Epoch 1/15.. Train loss: 4.058.. Valid loss: 3.727.. Valid accuracy: 0.164
# Epoch 1/15.. Train loss: 3.823.. Valid loss: 3.526.. Valid accuracy: 0.189
# Epoch 1/15.. Train loss: 3.729.. Valid loss: 3.283.. Valid accuracy: 0.238
# Epoch 1/15.. Train loss: 3.502.. Valid loss: 3.055.. Valid accuracy: 0.268
# Epoch 1/15.. Train loss: 3.133.. Valid loss: 2.890.. Valid accuracy: 0.304
# Epoch 1/15.. Train loss: 3.249.. Valid loss: 2.779.. Valid accuracy: 0.318
# Epoch 1/15.. Train loss: 3.122.. Valid loss: 2.664.. Valid accuracy: 0.334
# Epoch 1/15.. Train loss: 2.943.. Valid loss: 2.477.. Valid accuracy: 0.379
# Epoch 1/15.. Train loss: 2.749.. Valid loss: 2.359.. Valid accuracy: 0.405
# Epoch 1/15.. Train loss: 2.770.. Valid loss: 2.145.. Valid accuracy: 0.457
# Epoch 1/15.. Train loss: 2.748.. Valid loss: 2.257.. Valid accuracy: 0.448
# Epoch 1/15.. Train loss: 2.563.. Valid loss: 2.005.. Valid accuracy: 0.499
# Epoch 1/15.. Train loss: 2.386.. Valid loss: 1.928.. Valid accuracy: 0.507
# Epoch 1/15.. Train loss: 2.296.. Valid loss: 1.843.. Valid accuracy: 0.514
# Epoch 1/15.. Train loss: 2.523.. Valid loss: 1.869.. Valid accuracy: 0.533
# Epoch 1/15.. Train loss: 2.268.. Valid loss: 1.777.. Valid accuracy: 0.544
# Epoch 1..total time: 430.1258690357208
# Epoch 2/15.. Train loss: 2.331.. Valid loss: 1.904.. Valid accuracy: 0.517
# Epoch 2/15.. Train loss: 2.150.. Valid loss: 1.722.. Valid accuracy: 0.565
# Epoch 2/15.. Train loss: 1.980.. Valid loss: 1.667.. Valid accuracy: 0.582
# Epoch 2/15.. Train loss: 2.165.. Valid loss: 1.660.. Valid accuracy: 0.559
# Epoch 2/15.. Train loss: 1.933.. Valid loss: 1.689.. Valid accuracy: 0.567
# Epoch 2/15.. Train loss: 2.039.. Valid loss: 1.561.. Valid accuracy: 0.600
# Epoch 2/15.. Train loss: 1.962.. Valid loss: 1.661.. Valid accuracy: 0.580
# Epoch 2/15.. Train loss: 2.036.. Valid loss: 1.581.. Valid accuracy: 0.585
# Epoch 2/15.. Train loss: 1.828.. Valid loss: 1.496.. Valid accuracy: 0.605
# Epoch 2/15.. Train loss: 1.983.. Valid loss: 1.545.. Valid accuracy: 0.593
# Epoch 2/15.. Train loss: 1.845.. Valid loss: 1.541.. Valid accuracy: 0.597
# Epoch 2/15.. Train loss: 1.911.. Valid loss: 1.513.. Valid accuracy: 0.608
# Epoch 2/15.. Train loss: 1.717.. Valid loss: 1.508.. Valid accuracy: 0.621
# Epoch 2/15.. Train loss: 1.870.. Valid loss: 1.492.. Valid accuracy: 0.607
# Epoch 2/15.. Train loss: 1.903.. Valid loss: 1.505.. Valid accuracy: 0.607
# Epoch 2/15.. Train loss: 2.175.. Valid loss: 1.636.. Valid accuracy: 0.579
# Epoch 2/15.. Train loss: 2.053.. Valid loss: 1.467.. Valid accuracy: 0.628
# Epoch 2/15.. Train loss: 1.672.. Valid loss: 1.378.. Valid accuracy: 0.649
# Epoch 2/15.. Train loss: 1.691.. Valid loss: 1.373.. Valid accuracy: 0.643
# Epoch 2/15.. Train loss: 1.737.. Valid loss: 1.457.. Valid accuracy: 0.630
# Epoch 2/15.. Train loss: 2.219.. Valid loss: 1.423.. Valid accuracy: 0.642
# Epoch 2..total time: 430.35423707962036
# Epoch 3/15.. Train loss: 1.758.. Valid loss: 1.388.. Valid accuracy: 0.636
# Epoch 3/15.. Train loss: 1.508.. Valid loss: 1.284.. Valid accuracy: 0.664
# Epoch 3/15.. Train loss: 1.854.. Valid loss: 1.336.. Valid accuracy: 0.654
# Epoch 3/15.. Train loss: 1.649.. Valid loss: 1.398.. Valid accuracy: 0.651
# Epoch 3/15.. Train loss: 1.768.. Valid loss: 1.459.. Valid accuracy: 0.643
# Epoch 3/15.. Train loss: 1.657.. Valid loss: 1.397.. Valid accuracy: 0.649
# Epoch 3/15.. Train loss: 2.061.. Valid loss: 1.424.. Valid accuracy: 0.650
# Epoch 3/15.. Train loss: 1.606.. Valid loss: 1.471.. Valid accuracy: 0.637
# Epoch 3/15.. Train loss: 1.410.. Valid loss: 1.359.. Valid accuracy: 0.659
# Epoch 3/15.. Train loss: 1.433.. Valid loss: 1.275.. Valid accuracy: 0.689
# Epoch 3/15.. Train loss: 1.407.. Valid loss: 1.237.. Valid accuracy: 0.704
# Epoch 3/15.. Train loss: 1.509.. Valid loss: 1.255.. Valid accuracy: 0.695
# Epoch 3/15.. Train loss: 1.532.. Valid loss: 1.280.. Valid accuracy: 0.683
# Epoch 3/15.. Train loss: 1.673.. Valid loss: 1.183.. Valid accuracy: 0.703
# Epoch 3/15.. Train loss: 1.392.. Valid loss: 1.219.. Valid accuracy: 0.693
# Epoch 3/15.. Train loss: 1.584.. Valid loss: 1.425.. Valid accuracy: 0.650
# Epoch 3/15.. Train loss: 1.583.. Valid loss: 1.306.. Valid accuracy: 0.691
# Epoch 3/15.. Train loss: 1.641.. Valid loss: 1.222.. Valid accuracy: 0.712
# Epoch 3/15.. Train loss: 1.535.. Valid loss: 1.216.. Valid accuracy: 0.713
# Epoch 3/15.. Train loss: 1.514.. Valid loss: 1.339.. Valid accuracy: 0.685
# Epoch 3..total time: 413.1899230480194
# Epoch 4/15.. Train loss: 1.647.. Valid loss: 1.254.. Valid accuracy: 0.686
# Epoch 4/15.. Train loss: 1.402.. Valid loss: 1.242.. Valid accuracy: 0.689
# Epoch 4/15.. Train loss: 1.435.. Valid loss: 1.204.. Valid accuracy: 0.719
# Epoch 4/15.. Train loss: 1.235.. Valid loss: 1.251.. Valid accuracy: 0.695
# Epoch 4/15.. Train loss: 1.283.. Valid loss: 1.179.. Valid accuracy: 0.714
# Epoch 4/15.. Train loss: 1.379.. Valid loss: 1.143.. Valid accuracy: 0.703
# Epoch 4/15.. Train loss: 1.293.. Valid loss: 1.079.. Valid accuracy: 0.731
# Epoch 4/15.. Train loss: 1.376.. Valid loss: 1.195.. Valid accuracy: 0.710
# Epoch 4/15.. Train loss: 1.411.. Valid loss: 1.187.. Valid accuracy: 0.724
# Epoch 4/15.. Train loss: 1.423.. Valid loss: 1.255.. Valid accuracy: 0.706
# Epoch 4/15.. Train loss: 1.579.. Valid loss: 1.210.. Valid accuracy: 0.707
# Epoch 4/15.. Train loss: 1.576.. Valid loss: 1.240.. Valid accuracy: 0.691
# Epoch 4/15.. Train loss: 1.627.. Valid loss: 1.294.. Valid accuracy: 0.694
# Epoch 4/15.. Train loss: 1.589.. Valid loss: 1.372.. Valid accuracy: 0.695
# Epoch 4/15.. Train loss: 1.567.. Valid loss: 1.410.. Valid accuracy: 0.649
# Epoch 4/15.. Train loss: 1.748.. Valid loss: 1.395.. Valid accuracy: 0.675
# Epoch 4/15.. Train loss: 1.608.. Valid loss: 1.266.. Valid accuracy: 0.705
# Epoch 4/15.. Train loss: 1.411.. Valid loss: 1.288.. Valid accuracy: 0.693
# Epoch 4/15.. Train loss: 1.642.. Valid loss: 1.249.. Valid accuracy: 0.713
# Epoch 4/15.. Train loss: 1.411.. Valid loss: 1.187.. Valid accuracy: 0.714
# Epoch 4/15.. Train loss: 1.395.. Valid loss: 1.172.. Valid accuracy: 0.733
# Epoch 4..total time: 426.0927748680115
# Epoch 5/15.. Train loss: 1.337.. Valid loss: 1.314.. Valid accuracy: 0.694
# Epoch 5/15.. Train loss: 1.424.. Valid loss: 1.235.. Valid accuracy: 0.723
# Epoch 5/15.. Train loss: 1.393.. Valid loss: 1.338.. Valid accuracy: 0.669
# Epoch 5/15.. Train loss: 1.683.. Valid loss: 1.292.. Valid accuracy: 0.704
# Epoch 5/15.. Train loss: 1.718.. Valid loss: 1.283.. Valid accuracy: 0.704
# Epoch 5/15.. Train loss: 1.150.. Valid loss: 1.236.. Valid accuracy: 0.713
# Epoch 5/15.. Train loss: 1.730.. Valid loss: 1.258.. Valid accuracy: 0.693
# Epoch 5/15.. Train loss: 1.234.. Valid loss: 1.225.. Valid accuracy: 0.707
# Epoch 5/15.. Train loss: 1.280.. Valid loss: 1.172.. Valid accuracy: 0.746
# Epoch 5/15.. Train loss: 1.368.. Valid loss: 1.211.. Valid accuracy: 0.711
# Epoch 5/15.. Train loss: 1.141.. Valid loss: 1.154.. Valid accuracy: 0.730
# Epoch 5/15.. Train loss: 1.369.. Valid loss: 1.138.. Valid accuracy: 0.736
# Epoch 5/15.. Train loss: 1.388.. Valid loss: 1.158.. Valid accuracy: 0.733
# Epoch 5/15.. Train loss: 1.308.. Valid loss: 1.144.. Valid accuracy: 0.724
# Epoch 5/15.. Train loss: 1.445.. Valid loss: 1.108.. Valid accuracy: 0.750
# Epoch 5/15.. Train loss: 1.545.. Valid loss: 1.109.. Valid accuracy: 0.738
# Epoch 5/15.. Train loss: 1.413.. Valid loss: 1.088.. Valid accuracy: 0.735
# Epoch 5/15.. Train loss: 1.300.. Valid loss: 1.154.. Valid accuracy: 0.730
# Epoch 5/15.. Train loss: 1.742.. Valid loss: 1.245.. Valid accuracy: 0.728
# Epoch 5/15.. Train loss: 1.536.. Valid loss: 1.252.. Valid accuracy: 0.743
# Epoch 5/15.. Train loss: 1.497.. Valid loss: 1.449.. Valid accuracy: 0.668
# Epoch 5..total time: 426.5353434085846
# Epoch 6/15.. Train loss: 1.476.. Valid loss: 1.425.. Valid accuracy: 0.659
# Epoch 6/15.. Train loss: 1.557.. Valid loss: 1.286.. Valid accuracy: 0.695
# Epoch 6/15.. Train loss: 1.323.. Valid loss: 1.245.. Valid accuracy: 0.705
# Epoch 6/15.. Train loss: 1.298.. Valid loss: 1.224.. Valid accuracy: 0.716
# Epoch 6/15.. Train loss: 1.523.. Valid loss: 1.200.. Valid accuracy: 0.733
# Epoch 6/15.. Train loss: 1.121.. Valid loss: 1.242.. Valid accuracy: 0.725
# Epoch 6/15.. Train loss: 1.412.. Valid loss: 1.270.. Valid accuracy: 0.723
# Epoch 6/15.. Train loss: 1.536.. Valid loss: 1.238.. Valid accuracy: 0.736
# Epoch 6/15.. Train loss: 1.292.. Valid loss: 1.245.. Valid accuracy: 0.727
# Epoch 6/15.. Train loss: 1.451.. Valid loss: 1.227.. Valid accuracy: 0.729
# Epoch 6/15.. Train loss: 1.540.. Valid loss: 1.208.. Valid accuracy: 0.722
# Epoch 6/15.. Train loss: 1.371.. Valid loss: 1.155.. Valid accuracy: 0.723
# Epoch 6/15.. Train loss: 1.659.. Valid loss: 1.314.. Valid accuracy: 0.694
# Epoch 6/15.. Train loss: 1.478.. Valid loss: 1.303.. Valid accuracy: 0.691
# Epoch 6/15.. Train loss: 1.360.. Valid loss: 1.364.. Valid accuracy: 0.694
# Epoch 6/15.. Train loss: 1.782.. Valid loss: 1.347.. Valid accuracy: 0.705
# Epoch 6/15.. Train loss: 1.398.. Valid loss: 1.383.. Valid accuracy: 0.729
# Epoch 6/15.. Train loss: 1.339.. Valid loss: 1.456.. Valid accuracy: 0.711
# Epoch 6/15.. Train loss: 1.617.. Valid loss: 1.388.. Valid accuracy: 0.710
# Epoch 6/15.. Train loss: 1.279.. Valid loss: 1.354.. Valid accuracy: 0.719
# Epoch 6..total time: 414.45577001571655
# Epoch 7/15.. Train loss: 1.273.. Valid loss: 1.288.. Valid accuracy: 0.721
# Epoch 7/15.. Train loss: 1.389.. Valid loss: 1.337.. Valid accuracy: 0.710
# Epoch 7/15.. Train loss: 1.233.. Valid loss: 1.280.. Valid accuracy: 0.718
# Epoch 7/15.. Train loss: 1.489.. Valid loss: 1.280.. Valid accuracy: 0.703
# Epoch 7/15.. Train loss: 1.630.. Valid loss: 1.321.. Valid accuracy: 0.710
# Epoch 7/15.. Train loss: 1.142.. Valid loss: 1.334.. Valid accuracy: 0.707
# Epoch 7/15.. Train loss: 1.457.. Valid loss: 1.346.. Valid accuracy: 0.691
# Epoch 7/15.. Train loss: 1.527.. Valid loss: 1.290.. Valid accuracy: 0.727
# Epoch 7/15.. Train loss: 1.321.. Valid loss: 1.266.. Valid accuracy: 0.719
# Epoch 7/15.. Train loss: 1.512.. Valid loss: 1.247.. Valid accuracy: 0.734
# Epoch 7/15.. Train loss: 1.376.. Valid loss: 1.285.. Valid accuracy: 0.725
# Epoch 7/15.. Train loss: 1.339.. Valid loss: 1.284.. Valid accuracy: 0.738
# Epoch 7/15.. Train loss: 1.701.. Valid loss: 1.315.. Valid accuracy: 0.728
# Epoch 7/15.. Train loss: 1.695.. Valid loss: 1.296.. Valid accuracy: 0.727
# Epoch 7/15.. Train loss: 1.529.. Valid loss: 1.319.. Valid accuracy: 0.728
# Epoch 7/15.. Train loss: 1.475.. Valid loss: 1.278.. Valid accuracy: 0.741
# Epoch 7/15.. Train loss: 1.149.. Valid loss: 1.264.. Valid accuracy: 0.724
# Epoch 7/15.. Train loss: 1.609.. Valid loss: 1.208.. Valid accuracy: 0.742
# Epoch 7/15.. Train loss: 1.582.. Valid loss: 1.210.. Valid accuracy: 0.749
# Epoch 7/15.. Train loss: 1.626.. Valid loss: 1.236.. Valid accuracy: 0.734
# Epoch 7/15.. Train loss: 1.176.. Valid loss: 1.287.. Valid accuracy: 0.705
# Epoch 7..total time: 430.7758421897888
# Epoch 8/15.. Train loss: 1.601.. Valid loss: 1.288.. Valid accuracy: 0.715
# Epoch 8/15.. Train loss: 1.647.. Valid loss: 1.335.. Valid accuracy: 0.719
# Epoch 8/15.. Train loss: 1.381.. Valid loss: 1.341.. Valid accuracy: 0.723
# Epoch 8/15.. Train loss: 1.785.. Valid loss: 1.358.. Valid accuracy: 0.719
# Epoch 8/15.. Train loss: 1.697.. Valid loss: 1.376.. Valid accuracy: 0.721
# Epoch 8/15.. Train loss: 1.566.. Valid loss: 1.414.. Valid accuracy: 0.723
# Epoch 8/15.. Train loss: 1.399.. Valid loss: 1.382.. Valid accuracy: 0.732
# Epoch 8/15.. Train loss: 1.188.. Valid loss: 1.335.. Valid accuracy: 0.730
# Epoch 8/15.. Train loss: 1.407.. Valid loss: 1.409.. Valid accuracy: 0.712
# Epoch 8/15.. Train loss: 1.569.. Valid loss: 1.358.. Valid accuracy: 0.713
# Epoch 8/15.. Train loss: 1.641.. Valid loss: 1.260.. Valid accuracy: 0.721
# Epoch 8/15.. Train loss: 1.526.. Valid loss: 1.337.. Valid accuracy: 0.698
# Epoch 8/15.. Train loss: 1.807.. Valid loss: 1.370.. Valid accuracy: 0.688
# Epoch 8/15.. Train loss: 1.224.. Valid loss: 1.366.. Valid accuracy: 0.713
# Epoch 8/15.. Train loss: 1.475.. Valid loss: 1.366.. Valid accuracy: 0.724
# Epoch 8/15.. Train loss: 1.259.. Valid loss: 1.429.. Valid accuracy: 0.710
# Epoch 8/15.. Train loss: 1.176.. Valid loss: 1.347.. Valid accuracy: 0.717
# Epoch 8/15.. Train loss: 1.888.. Valid loss: 1.263.. Valid accuracy: 0.748
# Epoch 8/15.. Train loss: 1.411.. Valid loss: 1.210.. Valid accuracy: 0.750
# Epoch 8/15.. Train loss: 1.363.. Valid loss: 1.247.. Valid accuracy: 0.733
# Epoch 8..total time: 416.1819853782654
# Epoch 9/15.. Train loss: 1.719.. Valid loss: 1.299.. Valid accuracy: 0.732
# Epoch 9/15.. Train loss: 1.494.. Valid loss: 1.266.. Valid accuracy: 0.740
# Epoch 9/15.. Train loss: 1.308.. Valid loss: 1.360.. Valid accuracy: 0.714
# Epoch 9/15.. Train loss: 1.705.. Valid loss: 1.302.. Valid accuracy: 0.730
# Epoch 9/15.. Train loss: 1.419.. Valid loss: 1.291.. Valid accuracy: 0.755
# Epoch 9/15.. Train loss: 1.289.. Valid loss: 1.355.. Valid accuracy: 0.734
# Epoch 9/15.. Train loss: 1.440.. Valid loss: 1.372.. Valid accuracy: 0.730
# Epoch 9/15.. Train loss: 1.479.. Valid loss: 1.458.. Valid accuracy: 0.712
# Epoch 9/15.. Train loss: 1.868.. Valid loss: 1.425.. Valid accuracy: 0.704
# Epoch 9/15.. Train loss: 1.695.. Valid loss: 1.424.. Valid accuracy: 0.710
# Epoch 9/15.. Train loss: 1.633.. Valid loss: 1.438.. Valid accuracy: 0.711
# Epoch 9/15.. Train loss: 1.577.. Valid loss: 1.469.. Valid accuracy: 0.683
# Epoch 9/15.. Train loss: 1.497.. Valid loss: 1.499.. Valid accuracy: 0.692
# Epoch 9/15.. Train loss: 1.740.. Valid loss: 1.489.. Valid accuracy: 0.704
# Epoch 9/15.. Train loss: 1.793.. Valid loss: 1.423.. Valid accuracy: 0.710
# Epoch 9/15.. Train loss: 1.178.. Valid loss: 1.345.. Valid accuracy: 0.709
# Epoch 9/15.. Train loss: 1.436.. Valid loss: 1.307.. Valid accuracy: 0.703
# Epoch 9/15.. Train loss: 1.846.. Valid loss: 1.231.. Valid accuracy: 0.731
# Epoch 9/15.. Train loss: 1.731.. Valid loss: 1.166.. Valid accuracy: 0.744
# Epoch 9/15.. Train loss: 1.605.. Valid loss: 1.226.. Valid accuracy: 0.738
# Epoch 9/15.. Train loss: 1.436.. Valid loss: 1.307.. Valid accuracy: 0.738
# Epoch 9..total time: 427.36648893356323
# Epoch 10/15.. Train loss: 1.737.. Valid loss: 1.422.. Valid accuracy: 0.725
# Epoch 10/15.. Train loss: 1.317.. Valid loss: 1.427.. Valid accuracy: 0.721
# Epoch 10/15.. Train loss: 1.623.. Valid loss: 1.506.. Valid accuracy: 0.738
# Epoch 10/15.. Train loss: 1.590.. Valid loss: 1.574.. Valid accuracy: 0.707
# Epoch 10/15.. Train loss: 1.396.. Valid loss: 1.424.. Valid accuracy: 0.718
# Epoch 10/15.. Train loss: 1.452.. Valid loss: 1.437.. Valid accuracy: 0.690
# Epoch 10/15.. Train loss: 1.749.. Valid loss: 1.418.. Valid accuracy: 0.699
# Epoch 10/15.. Train loss: 1.623.. Valid loss: 1.378.. Valid accuracy: 0.718
# Epoch 10/15.. Train loss: 2.202.. Valid loss: 1.579.. Valid accuracy: 0.684
# Epoch 10/15.. Train loss: 1.826.. Valid loss: 1.529.. Valid accuracy: 0.709
# Epoch 10/15.. Train loss: 1.583.. Valid loss: 1.543.. Valid accuracy: 0.698
# Epoch 10/15.. Train loss: 1.610.. Valid loss: 1.563.. Valid accuracy: 0.714
# Epoch 10/15.. Train loss: 1.766.. Valid loss: 1.514.. Valid accuracy: 0.704
# Epoch 10/15.. Train loss: 1.512.. Valid loss: 1.456.. Valid accuracy: 0.716
# Epoch 10/15.. Train loss: 2.080.. Valid loss: 1.390.. Valid accuracy: 0.727
# Epoch 10/15.. Train loss: 1.531.. Valid loss: 1.402.. Valid accuracy: 0.729
# Epoch 10/15.. Train loss: 1.485.. Valid loss: 1.445.. Valid accuracy: 0.724
# Epoch 10/15.. Train loss: 1.654.. Valid loss: 1.381.. Valid accuracy: 0.724
# Epoch 10/15.. Train loss: 1.665.. Valid loss: 1.361.. Valid accuracy: 0.717
# Epoch 10/15.. Train loss: 1.675.. Valid loss: 1.313.. Valid accuracy: 0.739
# Epoch 10/15.. Train loss: 1.446.. Valid loss: 1.357.. Valid accuracy: 0.743
# Epoch 10..total time: 426.48544335365295
# Epoch 11/15.. Train loss: 1.524.. Valid loss: 1.352.. Valid accuracy: 0.743
# Epoch 11/15.. Train loss: 1.641.. Valid loss: 1.395.. Valid accuracy: 0.735
# Epoch 11/15.. Train loss: 1.323.. Valid loss: 1.319.. Valid accuracy: 0.760
# Epoch 11/15.. Train loss: 1.503.. Valid loss: 1.306.. Valid accuracy: 0.747
# Epoch 11/15.. Train loss: 1.355.. Valid loss: 1.312.. Valid accuracy: 0.747
# Epoch 11/15.. Train loss: 1.454.. Valid loss: 1.340.. Valid accuracy: 0.741
# Epoch 11/15.. Train loss: 1.486.. Valid loss: 1.360.. Valid accuracy: 0.723
# Epoch 11/15.. Train loss: 1.598.. Valid loss: 1.352.. Valid accuracy: 0.724
# Epoch 11/15.. Train loss: 1.444.. Valid loss: 1.417.. Valid accuracy: 0.736
# Epoch 11/15.. Train loss: 1.357.. Valid loss: 1.417.. Valid accuracy: 0.747
# Epoch 11/15.. Train loss: 1.191.. Valid loss: 1.362.. Valid accuracy: 0.753
# Epoch 11/15.. Train loss: 1.463.. Valid loss: 1.355.. Valid accuracy: 0.746
# Epoch 11/15.. Train loss: 1.421.. Valid loss: 1.258.. Valid accuracy: 0.761
# Epoch 11/15.. Train loss: 1.244.. Valid loss: 1.265.. Valid accuracy: 0.745
# Epoch 11/15.. Train loss: 1.454.. Valid loss: 1.292.. Valid accuracy: 0.731
# Epoch 11/15.. Train loss: 1.559.. Valid loss: 1.317.. Valid accuracy: 0.728
# Epoch 11/15.. Train loss: 1.415.. Valid loss: 1.369.. Valid accuracy: 0.719
# Epoch 11/15.. Train loss: 1.518.. Valid loss: 1.318.. Valid accuracy: 0.728
# Epoch 11/15.. Train loss: 1.878.. Valid loss: 1.291.. Valid accuracy: 0.730
# Epoch 11/15.. Train loss: 1.684.. Valid loss: 1.318.. Valid accuracy: 0.745
# Epoch 11..total time: 412.34700322151184
# Epoch 12/15.. Train loss: 1.486.. Valid loss: 1.336.. Valid accuracy: 0.745
# Epoch 12/15.. Train loss: 1.514.. Valid loss: 1.352.. Valid accuracy: 0.747
# Epoch 12/15.. Train loss: 1.321.. Valid loss: 1.376.. Valid accuracy: 0.739
# Epoch 12/15.. Train loss: 1.591.. Valid loss: 1.385.. Valid accuracy: 0.735
# Epoch 12/15.. Train loss: 1.543.. Valid loss: 1.386.. Valid accuracy: 0.707
# Epoch 12/15.. Train loss: 1.288.. Valid loss: 1.349.. Valid accuracy: 0.732
# Epoch 12/15.. Train loss: 1.802.. Valid loss: 1.259.. Valid accuracy: 0.750
# Epoch 12/15.. Train loss: 1.883.. Valid loss: 1.221.. Valid accuracy: 0.750
# Epoch 12/15.. Train loss: 1.721.. Valid loss: 1.255.. Valid accuracy: 0.753
# Epoch 12/15.. Train loss: 1.338.. Valid loss: 1.240.. Valid accuracy: 0.758
# Epoch 12/15.. Train loss: 1.431.. Valid loss: 1.216.. Valid accuracy: 0.749
# Epoch 12/15.. Train loss: 1.342.. Valid loss: 1.157.. Valid accuracy: 0.770
# Epoch 12/15.. Train loss: 1.620.. Valid loss: 1.117.. Valid accuracy: 0.779
# Epoch 12/15.. Train loss: 1.220.. Valid loss: 1.149.. Valid accuracy: 0.782
# Epoch 12/15.. Train loss: 1.779.. Valid loss: 1.237.. Valid accuracy: 0.773
# Epoch 12/15.. Train loss: 1.632.. Valid loss: 1.292.. Valid accuracy: 0.743
# Epoch 12/15.. Train loss: 1.625.. Valid loss: 1.309.. Valid accuracy: 0.733
# Epoch 12/15.. Train loss: 1.919.. Valid loss: 1.361.. Valid accuracy: 0.724
# Epoch 12/15.. Train loss: 1.398.. Valid loss: 1.386.. Valid accuracy: 0.736
# Epoch 12/15.. Train loss: 1.367.. Valid loss: 1.404.. Valid accuracy: 0.739
# Epoch 12/15.. Train loss: 1.547.. Valid loss: 1.359.. Valid accuracy: 0.731
# Epoch 12..total time: 428.6864559650421
# Epoch 13/15.. Train loss: 1.699.. Valid loss: 1.263.. Valid accuracy: 0.753
# Epoch 13/15.. Train loss: 1.280.. Valid loss: 1.232.. Valid accuracy: 0.746
# Epoch 13/15.. Train loss: 1.372.. Valid loss: 1.205.. Valid accuracy: 0.761
# Epoch 13/15.. Train loss: 1.260.. Valid loss: 1.210.. Valid accuracy: 0.767
# Epoch 13/15.. Train loss: 1.092.. Valid loss: 1.185.. Valid accuracy: 0.775
# Epoch 13/15.. Train loss: 1.281.. Valid loss: 1.220.. Valid accuracy: 0.776
# Epoch 13/15.. Train loss: 1.701.. Valid loss: 1.212.. Valid accuracy: 0.771
# Epoch 13/15.. Train loss: 1.780.. Valid loss: 1.350.. Valid accuracy: 0.749
# Epoch 13/15.. Train loss: 1.840.. Valid loss: 1.456.. Valid accuracy: 0.734
# Epoch 13/15.. Train loss: 1.539.. Valid loss: 1.501.. Valid accuracy: 0.721
# Epoch 13/15.. Train loss: 1.918.. Valid loss: 1.430.. Valid accuracy: 0.731
# Epoch 13/15.. Train loss: 1.477.. Valid loss: 1.381.. Valid accuracy: 0.729
# Epoch 13/15.. Train loss: 1.693.. Valid loss: 1.340.. Valid accuracy: 0.755
# Epoch 13/15.. Train loss: 1.334.. Valid loss: 1.341.. Valid accuracy: 0.761
# Epoch 13/15.. Train loss: 1.467.. Valid loss: 1.209.. Valid accuracy: 0.780
# Epoch 13/15.. Train loss: 1.574.. Valid loss: 1.186.. Valid accuracy: 0.768
# Epoch 13/15.. Train loss: 1.475.. Valid loss: 1.221.. Valid accuracy: 0.755
# Epoch 13/15.. Train loss: 1.153.. Valid loss: 1.300.. Valid accuracy: 0.749
# Epoch 13/15.. Train loss: 1.888.. Valid loss: 1.349.. Valid accuracy: 0.745
# Epoch 13/15.. Train loss: 1.176.. Valid loss: 1.345.. Valid accuracy: 0.737
# Epoch 13..total time: 412.2527267932892
# Epoch 14/15.. Train loss: 1.776.. Valid loss: 1.367.. Valid accuracy: 0.736
# Epoch 14/15.. Train loss: 1.804.. Valid loss: 1.364.. Valid accuracy: 0.737
# Epoch 14/15.. Train loss: 1.436.. Valid loss: 1.383.. Valid accuracy: 0.733
# Epoch 14/15.. Train loss: 1.340.. Valid loss: 1.569.. Valid accuracy: 0.719
# Epoch 14/15.. Train loss: 1.504.. Valid loss: 1.491.. Valid accuracy: 0.750
# Epoch 14/15.. Train loss: 1.295.. Valid loss: 1.398.. Valid accuracy: 0.761
# Epoch 14/15.. Train loss: 0.963.. Valid loss: 1.410.. Valid accuracy: 0.758
# Epoch 14/15.. Train loss: 1.814.. Valid loss: 1.467.. Valid accuracy: 0.755
# Epoch 14/15.. Train loss: 2.176.. Valid loss: 1.262.. Valid accuracy: 0.766
# Epoch 14/15.. Train loss: 1.501.. Valid loss: 1.257.. Valid accuracy: 0.760
# Epoch 14/15.. Train loss: 1.623.. Valid loss: 1.293.. Valid accuracy: 0.752
# Epoch 14/15.. Train loss: 1.428.. Valid loss: 1.330.. Valid accuracy: 0.749
# Epoch 14/15.. Train loss: 1.484.. Valid loss: 1.325.. Valid accuracy: 0.742
# Epoch 14/15.. Train loss: 1.728.. Valid loss: 1.362.. Valid accuracy: 0.745
# Epoch 14/15.. Train loss: 1.422.. Valid loss: 1.372.. Valid accuracy: 0.751
# Epoch 14/15.. Train loss: 1.431.. Valid loss: 1.328.. Valid accuracy: 0.750
# Epoch 14/15.. Train loss: 1.314.. Valid loss: 1.317.. Valid accuracy: 0.745
# Epoch 14/15.. Train loss: 1.547.. Valid loss: 1.313.. Valid accuracy: 0.740
# Epoch 14/15.. Train loss: 1.041.. Valid loss: 1.330.. Valid accuracy: 0.756
# Epoch 14/15.. Train loss: 1.740.. Valid loss: 1.335.. Valid accuracy: 0.747
# Epoch 14/15.. Train loss: 1.327.. Valid loss: 1.407.. Valid accuracy: 0.751
# Epoch 14..total time: 426.8290958404541
# Epoch 15/15.. Train loss: 1.573.. Valid loss: 1.452.. Valid accuracy: 0.751
# Epoch 15/15.. Train loss: 2.179.. Valid loss: 1.379.. Valid accuracy: 0.737
# Epoch 15/15.. Train loss: 1.634.. Valid loss: 1.384.. Valid accuracy: 0.730
# Epoch 15/15.. Train loss: 1.281.. Valid loss: 1.392.. Valid accuracy: 0.737
# Epoch 15/15.. Train loss: 1.397.. Valid loss: 1.414.. Valid accuracy: 0.736
# Epoch 15/15.. Train loss: 1.492.. Valid loss: 1.406.. Valid accuracy: 0.737
# Epoch 15/15.. Train loss: 1.380.. Valid loss: 1.430.. Valid accuracy: 0.736
# Epoch 15/15.. Train loss: 1.844.. Valid loss: 1.498.. Valid accuracy: 0.746
# Epoch 15/15.. Train loss: 1.542.. Valid loss: 1.400.. Valid accuracy: 0.740
# Epoch 15/15.. Train loss: 1.157.. Valid loss: 1.387.. Valid accuracy: 0.743
# Epoch 15/15.. Train loss: 1.425.. Valid loss: 1.407.. Valid accuracy: 0.740
# Epoch 15/15.. Train loss: 1.857.. Valid loss: 1.371.. Valid accuracy: 0.759
# Epoch 15/15.. Train loss: 1.604.. Valid loss: 1.395.. Valid accuracy: 0.747
# Epoch 15/15.. Train loss: 1.525.. Valid loss: 1.451.. Valid accuracy: 0.734
# Epoch 15/15.. Train loss: 1.430.. Valid loss: 1.419.. Valid accuracy: 0.733
# Epoch 15/15.. Train loss: 1.407.. Valid loss: 1.423.. Valid accuracy: 0.743
# Epoch 15/15.. Train loss: 1.759.. Valid loss: 1.418.. Valid accuracy: 0.734
# Epoch 15/15.. Train loss: 1.358.. Valid loss: 1.448.. Valid accuracy: 0.730
# Epoch 15/15.. Train loss: 1.430.. Valid loss: 1.511.. Valid accuracy: 0.724
# Epoch 15/15.. Train loss: 1.328.. Valid loss: 1.460.. Valid accuracy: 0.747
# Epoch 15/15.. Train loss: 1.223.. Valid loss: 1.415.. Valid accuracy: 0.751
# Epoch 15..total time: 426.9404628276825

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
test_loss = 0
accuracy = 0
model.eval()
with torch.no_grad():
    for inputs, labels in testloaders:
        inputs, labels = inputs.to(device), labels.to(device)
        logps = model.forward(inputs)
        batch_loss = criterion(logps, labels)

        test_loss += batch_loss.item()

        # Calculate accuracy
        ps = torch.exp(logps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

print(f"Test loss: {test_loss/len(testloaders):.3f}.. "
      f"Test accuracy: {accuracy/len(testloaders):.3f}")
# Out:
# Test loss: 1.121.. Test accuracy: 0.741

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
#torch.save(model.state_dict(), 'flower_classifier_2.pth')
state = {
    'model':model,
    'epoch': epochs,
    'state_dict': model.state_dict(),
    'optimizer': optimizer.state_dict(),
    'class_to_idx':train_datasets.class_to_idx
    }
torch.save(state, 'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
import torch
from torchvision import datasets, transforms,models
from torch import nn
from time import time,sleep
from PIL import Image
import numpy as np
import os
import random
import matplotlib.pyplot as plt
from collections import OrderedDict
from torch import nn, optim
import torch.nn.functional as F

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
data_transforms = transforms.Compose([transforms.Resize(255),
                                 transforms.CenterCrop(224),
                                 transforms.ToTensor(),
                                 transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])
# TODO: Load the datasets with ImageFolder
train_datasets = datasets.ImageFolder(train_dir, transform=data_transforms)
valid_datasets = datasets.ImageFolder(valid_dir, transform=data_transforms)
test_datasets = datasets.ImageFolder(test_dir, transform=data_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloaders = torch.utils.data.DataLoader(train_datasets, batch_size=64, shuffle=True)
validloaders = torch.utils.data.DataLoader(valid_datasets, batch_size=64, shuffle=True)
testloaders = torch.utils.data.DataLoader(test_datasets, batch_size=64, shuffle=True)

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
model = torch.load('checkpoint.pth')['model']
model.class_to_idx = torch.load('checkpoint.pth')['class_to_idx']

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device);

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model
    with Image.open(image) as im:
        max_size=max(im.size)
        min_size=min(im.size)
        #print(im.size)
        im.thumbnail([256*(max_size/min_size),256*(max_size/min_size)])
        #print(im.size)
        im=im.crop([(im.size[0]-224)/2,(im.size[1]-224)/2,224+(im.size[0]-224)/2,224+(im.size[1]-224)/2])
        #print(im.size)
        #plt.imshow(im)
        np_image = np.array(im)
        #print(np_image)
        #print(np_image.shape)
        mean = 255*np.array([0.485, 0.456, 0.406])
        std = 255*np.array([0.229, 0.224, 0.225])
        np_image = (np_image - mean) / std
        np_image = np.transpose(np_image,(2,0,1))
        #print(np_image)
        return np_image

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    #ax.imshow(image)
    
    return ax

# %%
def view_classify(img,top_class, top_p,flower_name):
    ''' Function for viewing an image and it's predicted classes.
    '''
    top_p = top_p.data.cpu().detach().numpy()

    fig, (ax1, ax2) = plt.subplots(2)
    ax1.imshow(img)
    ax1.axis('off')
    ax2.barh(np.arange(5), top_p[0][::-1])
    ax2.set_aspect(0.1)
    ax2.set_yticks(np.arange(5))
    ax2.set_yticklabels([cat_to_name[x] for x in top_class[::-1]], size='medium');
    ax1.set_title(flower_name)
    ax2.set_title('Class Probability')
    ax2.set_xlim(0, 1.1)

    plt.show()

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    folders=os.listdir(image_path)
    image_folder=random.choice(folders)
    # TODO: Implement the code to predict the class from an image file
    images = os.listdir(image_path+'/'+image_folder)
    image=random.choice(images)
    #print(image , image_folder,cat_to_name[image_folder])
    np_image = process_image(image_path+'/'+image_folder+'/'+image)
    #model.eval()
    np_image=torch.from_numpy(np_image).unsqueeze(0)
    #print(np_image)
    #print(np_image.to(device = device,dtype = torch.float))
    model.eval()
    with torch.no_grad():
        logps = model.forward(np_image.to(device = device,dtype = torch.float))
        # Calculate accuracy
        ps = torch.exp(logps)
        #print(ps)
        top_p, top_class = ps.topk(5, dim=1)
        #print(top_p, top_class)
        #print(str(top_class[0][0].item()))
        #print(cat_to_name[str(top_class[0][0].item())])
        idx_to_class = {model.class_to_idx[k]:k for k in model.class_to_idx.keys()}
    with Image.open(image_path+'/'+image_folder+'/'+image) as im:
        top_class = [idx_to_class[x] for x in top_class[0].tolist()]
        view_classify(im,top_class, top_p,cat_to_name[image_folder])
    
    #return(top_p,top_class)

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes

# %%
predict(test_dir,model,5)

# %% [markdown]
# <font color='red'>**Reminder for Workspace users:** If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.</font>

# %%
# TODO remove .pth files or move it to a temporary `~/opt` directory in this Workspace
